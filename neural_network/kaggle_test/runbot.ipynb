# %%
# !rm -rf warorbit
# !git clone https://github.com/Jrix-G/warorbit.git
# %cd warorbit/neural_network
# !ls -la
# Out:
# Cloning into 'warorbit'...
# remote: Enumerating objects: 3800, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 3800 (delta 1), reused 7 (delta 1), pack-reused 3784 (from 3)
# Receiving objects: 100% (3800/3800), 189.29 MiB | 19.22 MiB/s, done.
# Resolving deltas: 100% (1223/1223), done.
# Updating files: 100% (2191/2191), done.
# /kaggle/working/warorbit/neural_network
# total 68
# drwxr-xr-x  9 root root 4096 May  3 09:36 .
# drwxr-xr-x 20 root root 4096 May  3 09:36 ..
# -rw-r--r--  1 root root 1782 May  3 09:36 AGENT_PROMPT.md
# -rw-r--r--  1 root root    0 May  3 09:36 .codex
# drwxr-xr-x  2 root root 4096 May  3 09:36 configs
# drwxr-xr-x  2 root root 4096 May  3 09:36 docs
# -rw-r--r--  1 root root   46 May  3 09:36 __init__.py
# -rw-r--r--  1 root root   76 May  3 09:36 lanceur_20min.cmd
# -rw-r--r--  1 root root 2529 May  3 09:36 lanceur_20min.py
# ...

# %%
cd /kaggle/working/warorbit
# Out:
# /kaggle/working/warorbit

# %%
# !python neural_network/scripts/run_90min_6agent_training.py --duration-minutes 200 --workers 6 --eval-episodes 8
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 87.4 MB/s eta 0:00:00
# generation 0 start elapsed=0.0m best=-1000000000.000 pool=14 workers=6
# generation 0 train done 1/6 elapsed=6.1m
# generation 0 train done 2/6 elapsed=6.4m
# generation 0 train done 3/6 elapsed=6.5m
# generation 0 train done 4/6 elapsed=7.1m
# generation 0 train done 5/6 elapsed=7.4m
# generation 0 train done 6/6 elapsed=8.3m
# generation 0 eval done 1/6 elapsed=22.8m
# generation 0 eval done 2/6 elapsed=23.6m
# generation 0 eval done 3/6 elapsed=24.7m
# generation 0 eval done 4/6 elapsed=25.3m
# generation 0 eval done 5/6 elapsed=25.3m
# generation 0 eval done 6/6 elapsed=25.7m
# generation 0 best_winrate=0.000 global_best=0.000 params=1314050 pool=14
# generation 1 start elapsed=25.8m best=0.000 pool=14 workers=6
# generation 1 train done 1/6 elapsed=31.7m
# generation 1 train done 2/6 elapsed=32.9m
# generation 1 train done 3/6 elapsed=33.6m
# generation 1 train done 4/6 elapsed=34.1m
# ...
